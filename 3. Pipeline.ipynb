# %% [markdown]
# ## The Pipeline
# The pipeline in PowerShell is the mechanism by which objects generated by commands can be provided to other commands as input. Commands themselves do not understand *how* to pass objects between each other, only how to accept the appropriate object and how to generate an object as output. The PowerShell engine behind the scenes handles the passing of objects from the first command, along the pipeline, to the last command.

# %% [markdown]
# Commands can only accept objects of certain types as input:

# %%
Get-Command -ParameterType String | Select-Object -First 10
# Out:
# CommandType     Name                                               Version    Source
# -----------     ----                                               -------    ------
# Function        help
# Function        mkdir
# Function        oss
# Function        TabExpansion2
# Cmdlet          Add-History                                        7.4.1.500  Microsoft.PowerShell…
# Cmdlet          Add-Member                                         7.0.0.0    Microsoft.PowerShell…
# Cmdlet          Add-Type                                           7.0.0.0    Microsoft.PowerShell…
# Cmdlet          Clear-History                                      7.4.1.500  Microsoft.PowerShell…
# Cmdlet          Clear-Variable                                     7.0.0.0    Microsoft.PowerShell…
# Cmdlet          Compare-Object                                     7.0.0.0    Microsoft.PowerShell…

# %% [markdown]
# And output objects of certain types:

# %%
Get-Command | Where-Object {$_.OutputType -match "String" } | Select-Object -First 10
# Out:
# CommandType     Name                                               Version    Source
# -----------     ----                                               -------    ------
# Cmdlet          Convert-Path                                       7.0.0.0    Microsoft.PowerShell…
# Cmdlet          ConvertTo-Csv                                      7.0.0.0    Microsoft.PowerShell…
# Cmdlet          ConvertTo-Html                                     7.0.0.0    Microsoft.PowerShell…
# Cmdlet          ConvertTo-Json                                     7.0.0.0    Microsoft.PowerShell…
# Cmdlet          ConvertTo-Xml                                      7.0.0.0    Microsoft.PowerShell…
# Cmdlet          Get-Clipboard                                      7.0.0.0    Microsoft.PowerShell…
# Cmdlet          Get-Command                                        7.4.1.500  Microsoft.PowerShell…
# Cmdlet          Get-Content                                        7.0.0.0    Microsoft.PowerShell…
# Cmdlet          Get-Date                                           7.0.0.0    Microsoft.PowerShell…
# Cmdlet          Get-Item                                           7.0.0.0    Microsoft.PowerShell…

# %% [markdown]
# The pipeline uses the pipe operator "|" to join commands together, passing the output of one command as the input to another command.

# %%
Get-Process code | Select-Object -ExpandProperty Modules | Select-Object FileName | Select-Object -Last 10
# Out:
# FileName
# --------
# C:\Windows\System32\win32u.dll
# C:\Windows\System32\GDI32.dll
# C:\Windows\System32\gdi32full.dll
# C:\Windows\System32\IMM32.DLL
# C:\Windows\system32\uxtheme.dll
# C:\Windows\system32\mswsock.dll
# C:\Windows\System32\SHELL32.dll
# C:\Windows\System32\shcore.dll
# C:\Windows\System32\ADVAPI32.dll
# C:\Windows\SYSTEM32\kernel.appcore.dll
# Command failed: SubmitCode: Get-Process code | Select-Object -ExpandProperty M ...

# %% [markdown]
# ## Parameter Binding
# When objects are sent down the pipeline, PowerShell attempts to associate the object with command parameters that accept pipeline input; this is known as _parameter binding_.

# %%
Get-Help Get-Process -Parameter * | Where-Object { $_.pipelineInput -Like 'true*' } | Select-Object Name, PipelineInput, Type
# Out:
# name        pipelineInput         type
# ----        -------------         ----
# Id          true (ByPropertyName) @{name=int[]}
# InputObject true (ByValue)        @{name=Process[]}
# Name        true (ByPropertyName) @{name=string[]}

# %% [markdown]
# The _Get-Process_ cmdlet shown above has several parameters that accept pipeline input. The **Name** parameter for example, accepts pipelineinput as long the object is of type **\<string\>**.
#
# _ByValue_ means the parameter accepts pipeline input if the object matches the expect type or can be converted to that type.
#
# _ByPropertyName_ means the parameter will accept input if the object has a property that matches the parameter name.
#
# In the below code, the custom object 'Foo' is created, with a single property 'bar', that has the value 'powershell'. As the command Get-Process has no parameter that accepts a custom object as the input type, or an object with the property called 'bar', the pipeline execution fails:

# %%
$Foo = [pscustomobject]@{ Bar="powershell" };
"The type of Foo is: " + ($Foo).GetType().FullName;
$Foo | Get-Process
# Out:
# Custom Objects type is: System.Management.Automation.PSCustomObject
# Get-Process:
# Line |
#    3 |  $CustomObject | Get-Process
#      |                  ~~~~~~~~~~~
#      | The input object cannot be bound to any parameters for the command either because the command does not take pipeline input or the input and its properties do not match any of the parameters that take pipeline input.
# Command failed: SubmitCode: $CustomObject = [pscustomobject]@{ Foo="powershell ...

# %% [markdown]
# Notice how the below works thoough; because _Get-Process_ does have a parameter called Name that accepts input ByPropertyName, if we change the property of the custom object to be called **Name**, _Get-Process_ returns the expected result.

# %%
$Foo = [pscustomobject]@{ Name="powershell" };
"The type of Foo is: " + ($Foo).GetType().FullName;
$Foo | Get-Process
# Out:
# The type of Foo is: System.Management.Automation.PSCustomObject
#
#  NPM(K)    PM(M)      WS(M)     CPU(s)      Id  SI ProcessName
#  ------    -----      -----     ------      --  -- -----------
#      26    53.20      57.09       0.53   14696  29 powershell

# %% [markdown]
# ## Debugging the Pipeline
# The _Trace-Command_ cmdlet creates a subpipeline and runs the provided expression inside this subpipeline, meaning each step of the expression ca be inspected. In the below output, it can be seen that the Foo PSCustomObject is repeatedly matched against the _Get-Process_ cmdlets parameters, looking to see if the value type or property name matches.

# %%
$Foo = [pscustomobject]@{ Bar="powershell" };
Trace-Command ParameterBinding -Expression {$Foo | Get-Process} -PSHost
# Out:
# DEBUG: 2024-03-11 19:33:31.5858 ParameterBinding Information: 0 : BIND NAMED cmd line args [Get-Process]
# DEBUG: 2024-03-11 19:33:31.5876 ParameterBinding Information: 0 : BIND POSITIONAL cmd line args [Get-Process]
# DEBUG: 2024-03-11 19:33:31.5877 ParameterBinding Information: 0 : MANDATORY PARAMETER CHECK on cmdlet [Get-Process]
# DEBUG: 2024-03-11 19:33:31.5878 ParameterBinding Information: 0 : CALLING BeginProcessing
# DEBUG: 2024-03-11 19:33:31.5882 ParameterBinding Information: 0 : BIND PIPELINE object to parameters: [Get-Process]
# DEBUG: 2024-03-11 19:33:31.5883 ParameterBinding Information: 0 :     PIPELINE object TYPE = [System.Management.Automation.PSCustomObject]
# DEBUG: 2024-03-11 19:33:31.5884 ParameterBinding Information: 0 :     RESTORING pipeline parameter's original values
# DEBUG: 2024-03-11 19:33:31.5885 ParameterBinding Information: 0 :     Parameter [InputObject] PIPELINE INPUT ValueFromPipeline NO COERCION
# DEBUG: 2024-03-11 19:33:31.5886 ParameterBinding Information: 0 :     BIND arg [@{Bar=powershell}] to parameter [InputObject]
# DEBUG: 2024-03-11 19:33:31.5887 ParameterBinding Information: 0 :         Binding collection parameter InputObject: argument type [PSObject], parameter type [System.Diagnostics.Process[]], collection type Array, element type [System.Diagnostics.Process], no coerceElementType
# DEBUG: 2024-03-11 19:33:31.5888 ParameterBinding Information: 0 :         Creating array with element type [System.Diagnostics.Process] and 1 elements
# DEBUG: 2024-03-11 19:33:31.5888 ParameterBinding Information: 0 :         Argument type PSObject is not IList, treating this as scalar
# DEBUG: 2024-03-11 19:33:31.5890 ParameterBinding Information: 0 :         BIND arg [@{Bar=powershell}] to param [InputObject] SKIPPED
# DEBUG: 2024-03-11 19:33:31.5891 ParameterBinding Information: 0 :     Parameter [Name] PIPELINE INPUT ValueFromPipelineByPropertyName NO COERCION
# DEBUG: 2024-03-11 19:33:31.5892 ParameterBinding Information: 0 :     Parameter [Id] PIPELINE INPUT ValueFromPipelineByPropertyName NO COERCION
# DEBUG: 2024-03-11 19:33:31.5893 ParameterBinding Information: 0 :     Parameter [InputObject] PIPELINE INPUT ValueFromPipeline WITH COERCION
# DEBUG: 2024-03-11 19:33:31.5894 ParameterBinding Information: 0 :     BIND arg [@{Bar=powershell}] to parameter [InputObject]
# DEBUG: 2024-03-11 19:33:31.5894 ParameterBinding Information: 0 :         COERCE arg to [System.Diagnostics.Process[]]
# DEBUG: 2024-03-11 19:33:31.5895 ParameterBinding Information: 0 :             Trying to convert argument value from System.Management.Automation.PSObject to System.Diagnostics.Process[]
# DEBUG: 2024-03-11 19:33:31.5896 ParameterBinding Information: 0 :             ENCODING arg into collection
# DEBUG: 2024-03-11 19:33:31.5896 ParameterBinding Information: 0 :             Binding collection parameter InputObject: argument type [PSObject], parameter type [System.Diagnostics.Process[]], collection type Array, element type [System.Diagnostics.Process], coerceElementType
# DEBUG: 2024-03-11 19:33:31.5897 ParameterBinding Information: 0 :             Creating array with element type [System.Diagnostics.Process] and 1 elements
# DEBUG: 2024-03-11 19:33:31.5898 ParameterBinding Information: 0 :             Argument type PSObject is not IList, treating this as scalar
# DEBUG: 2024-03-11 19:33:31.5899 ParameterBinding Information: 0 :             Coercing scalar arg value to type System.Diagnostics.Process
# DEBUG: 2024-03-11 19:33:31.5899 ParameterBinding Information: 0 :             COERCE arg to [System.Diagnostics.Process]
# DEBUG: 2024-03-11 19:33:31.5900 ParameterBinding Information: 0 :                 Trying to convert argument value from System.Management.Automation.PSObject to System.Diagnostics.Process
# DEBUG: 2024-03-11 19:33:31.5901 ParameterBinding Information: 0 :                 CONVERT arg type to param type using LanguagePrimitives.ConvertTo
# DEBUG: 2024-03-11 19:33:31.5905 ParameterBinding Information: 0 :                 ERROR: ERROR: COERCE FAILED: arg [@{Bar=powershell}] could not be converted to the parameter type [System.Diagnostics.Process]
# DEBUG: 2024-03-11 19:33:31.5907 ParameterBinding Information: 0 :     Parameter [Name] PIPELINE INPUT ValueFromPipelineByPropertyName WITH COERCION
# DEBUG: 2024-03-11 19:33:31.5908 ParameterBinding Information: 0 :     Parameter [Id] PIPELINE INPUT ValueFromPipelineByPropertyName WITH COERCION
# DEBUG: 2024-03-11 19:33:31.5910 ParameterBinding Information: 0 : BIND PIPELINE object to parameters: [Out-Default]
# DEBUG: 2024-03-11 19:33:31.5910 ParameterBinding Information: 0 :     PIPELINE object TYPE = [System.Management.Automation.ErrorRecord]
# DEBUG: 2024-03-11 19:33:31.5911 ParameterBinding Information: 0 :     RESTORING pipeline parameter's original values
# DEBUG: 2024-03-11 19:33:31.5912 ParameterBinding Information: 0 :     Parameter [InputObject] PIPELINE INPUT ValueFromPipeline NO COERCION
# DEBUG: 2024-03-11 19:33:31.5913 ParameterBinding Information: 0 :     BIND arg [The input object cannot be bound to any parameters for the command either because the command does not take pipeline input or the input and its properties do not match any of the parameters that take pipeline input.] to parameter [InputObject]
# DEBUG: 2024-03-11 19:33:31.5914 ParameterBinding Information: 0 :         BIND arg [The input object cannot be bound to any parameters for the command either because the command does not take pipeline input or the input and its properties do not match any of the parameters that take pipeline input.] to param [InputObject] SUCCESSFUL
# DEBUG: 2024-03-11 19:33:31.5914 ParameterBinding Information: 0 : MANDATORY PARAMETER CHECK on cmdlet [Out-Default2]
# DEBUG: 2024-03-11 19:33:31.5915 ParameterBinding Information: 0 : CALLING ProcessRecord
# DEBUG: 2024-03-11 19:33:31.5917 ParameterBinding Information: 0 :     BIND NAMED cmd line args [Out-LineOutput]
# DEBUG: 2024-03-11 19:33:31.5918 ParameterBinding Information: 0 :         BIND arg [Microsoft.PowerShell.Commands.Internal.Format.ConsoleLineOutput] to parameter [LineOutput]
# DEBUG: 2024-03-11 19:33:31.5919 ParameterBinding Information: 0 :             COERCE arg to [System.Object]
# DEBUG: 2024-03-11 19:33:31.5920 ParameterBinding Information: 0 :                 Parameter and arg types the same, no coercion is needed.
# DEBUG: 2024-03-11 19:33:31.5921 ParameterBinding Information: 0 :             BIND arg [Microsoft.PowerShell.Commands.Internal.Format.ConsoleLineOutput] to param [LineOutput] SUCCESSFUL
# DEBUG: 2024-03-11 19:33:31.5921 ParameterBinding Information: 0 :     BIND POSITIONAL cmd line args [Out-LineOutput]
# DEBUG: 2024-03-11 19:33:31.5922 ParameterBinding Information: 0 :     MANDATORY PARAMETER CHECK on cmdlet [Out-LineOutput]
# DEBUG: 2024-03-11 19:33:31.5923 ParameterBinding Information: 0 :     CALLING BeginProcessing
# DEBUG: 2024-03-11 19:33:31.5924 ParameterBinding Information: 0 :     BIND PIPELINE object to parameters: [Out-LineOutput]
# DEBUG: 2024-03-11 19:33:31.5925 ParameterBinding Information: 0 :         PIPELINE object TYPE = [System.Management.Automation.ErrorRecord]
# DEBUG: 2024-03-11 19:33:31.5926 ParameterBinding Information: 0 :         RESTORING pipeline parameter's original values
# DEBUG: 2024-03-11 19:33:31.5927 ParameterBinding Information: 0 :         Parameter [InputObject] PIPELINE INPUT ValueFromPipeline NO COERCION
# DEBUG: 2024-03-11 19:33:31.5928 ParameterBinding Information: 0 :         BIND arg [The input object cannot be bound to any parameters for the command either because the command does not take pipeline input or the input and its properties do not match any of the parameters that take pipeline input.] to parameter [InputObject]
# DEBUG: 2024-03-11 19:33:31.5929 ParameterBinding Information: 0 :             BIND arg [The input object cannot be bound to any parameters for the command either because the command does not take pipeline input or the input and its properties do not match any of the parameters that take pipeline input.] to param [InputObject] SUCCESSFUL
# DEBUG: 2024-03-11 19:33:31.5930 ParameterBinding Information: 0 :     MANDATORY PARAMETER CHECK on cmdlet [out-lineoutput]
# DEBUG: 2024-03-11 19:33:31.5931 ParameterBinding Information: 0 :     CALLING ProcessRecord
# DEBUG: 2024-03-11 19:33:31.5933 ParameterBinding Information: 0 :         BIND NAMED cmd line args [Format-Default]
# DEBUG: 2024-03-11 19:33:31.5934 ParameterBinding Information: 0 :         BIND POSITIONAL cmd line args [Format-Default]
# DEBUG: 2024-03-11 19:33:31.5935 ParameterBinding Information: 0 :         MANDATORY PARAMETER CHECK on cmdlet [Format-Default]
# DEBUG: 2024-03-11 19:33:31.5936 ParameterBinding Information: 0 :         CALLING BeginProcessing
# DEBUG: 2024-03-11 19:33:31.5938 ParameterBinding Information: 0 :         BIND PIPELINE object to parameters: [Format-Default]
# DEBUG: 2024-03-11 19:33:31.5939 ParameterBinding Information: 0 :             PIPELINE object TYPE = [System.Management.Automation.ErrorRecord]
# DEBUG: 2024-03-11 19:33:31.5940 ParameterBinding Information: 0 :             RESTORING pipeline parameter's original values
# DEBUG: 2024-03-11 19:33:31.5941 ParameterBinding Information: 0 :             Parameter [InputObject] PIPELINE INPUT ValueFromPipeline NO COERCION
# DEBUG: 2024-03-11 19:33:31.5942 ParameterBinding Information: 0 :             BIND arg [The input object cannot be bound to any parameters for the command either because the command does not take pipeline input or the input and its properties do not match any of the parameters that take pipeline input.] to parameter [InputObject]
# DEBUG: 2024-03-11 19:33:31.5944 ParameterBinding Information: 0 :                 BIND arg [The input object cannot be bound to any parameters for the command either because the command does not take pipeline input or the input and its properties do not match any of the parameters that take pipeline input.] to param [InputObject] SUCCESSFUL
# DEBUG: 2024-03-11 19:33:31.5945 ParameterBinding Information: 0 :         MANDATORY PARAMETER CHECK on cmdlet [format-default]
# DEBUG: 2024-03-11 19:33:31.5946 ParameterBinding Information: 0 :         CALLING ProcessRecord
# DEBUG: 2024-03-11 19:33:31.6079 ParameterBinding Information: 0 :             BIND NAMED cmd line args [Set-StrictMode]
# DEBUG: 2024-03-11 19:33:31.6082 ParameterBinding Information: 0 :                 BIND arg [True] to parameter [Off]
# DEBUG: 2024-03-11 19:33:31.6083 ParameterBinding Information: 0 :                     COERCE arg to [System.Management.Automation.SwitchParameter]
# DEBUG: 2024-03-11 19:33:31.6085 ParameterBinding Information: 0 :                         Parameter and arg types the same, no coercion is needed.
# DEBUG: 2024-03-11 19:33:31.6086 ParameterBinding Information: 0 :                     BIND arg [True] to param [Off] SUCCESSFUL
# DEBUG: 2024-03-11 19:33:31.6089 ParameterBinding Information: 0 :             BIND POSITIONAL cmd line args [Set-StrictMode]
# DEBUG: 2024-03-11 19:33:31.6092 ParameterBinding Information: 0 :             MANDATORY PARAMETER CHECK on cmdlet [Set-StrictMode]
# DEBUG: 2024-03-11 19:33:31.6096 ParameterBinding Information: 0 :             CALLING BeginProcessing
# DEBUG: 2024-03-11 19:33:31.6099 ParameterBinding Information: 0 :             CALLING ProcessRecord
# DEBUG: 2024-03-11 19:33:31.6101 ParameterBinding Information: 0 :             CALLING EndProcessing
# DEBUG: 2024-03-11 19:33:31.6301 ParameterBinding Information: 0 :             BIND NAMED cmd line args [Get-Command]
# DEBUG: 2024-03-11 19:33:31.6308 ParameterBinding Information: 0 :                 BIND arg [Get-Process] to parameter [Name]
# DEBUG: 2024-03-11 19:33:31.6310 ParameterBinding Information: 0 :                     COERCE arg to [System.String[]]
# DEBUG: 2024-03-11 19:33:31.6311 ParameterBinding Information: 0 :                         Trying to convert argument value from System.Management.Automation.CmdletInfo to System.String[]
# DEBUG: 2024-03-11 19:33:31.6312 ParameterBinding Information: 0 :                         ENCODING arg into collection
# DEBUG: 2024-03-11 19:33:31.6314 ParameterBinding Information: 0 :                         Binding collection parameter Name: argument type [CmdletInfo], parameter type [System.String[]], collection type Array, element type [System.String], coerceElementType
# DEBUG: 2024-03-11 19:33:31.6315 ParameterBinding Information: 0 :                         Creating array with element type [System.String] and 1 elements
# DEBUG: 2024-03-11 19:33:31.6316 ParameterBinding Information: 0 :                         Argument type CmdletInfo is not IList, treating this as scalar
# DEBUG: 2024-03-11 19:33:31.6317 ParameterBinding Information: 0 :                         Coercing scalar arg value to type System.String
# DEBUG: 2024-03-11 19:33:31.6318 ParameterBinding Information: 0 :                         COERCE arg to [System.String]
# DEBUG: 2024-03-11 19:33:31.6319 ParameterBinding Information: 0 :                             Trying to convert argument value from System.Management.Automation.CmdletInfo to System.String
# DEBUG: 2024-03-11 19:33:31.6321 ParameterBinding Information: 0 :                             CONVERT arg type to param type using LanguagePrimitives.ConvertTo
# DEBUG: 2024-03-11 19:33:31.6322 ParameterBinding Information: 0 :                             CONVERT SUCCESSFUL using LanguagePrimitives.ConvertTo: [Get-Process]
# DEBUG: 2024-03-11 19:33:31.6323 ParameterBinding Information: 0 :                         Adding scalar element of type String to array position 0
# DEBUG: 2024-03-11 19:33:31.6324 ParameterBinding Information: 0 :                     Executing VALIDATION metadata: [System.Management.Automation.ValidateNotNullOrEmptyAttribute]
# DEBUG: 2024-03-11 19:33:31.6325 ParameterBinding Information: 0 :                     BIND arg [System.String[]] to param [Name] SUCCESSFUL
# DEBUG: 2024-03-11 19:33:31.6326 ParameterBinding Information: 0 :                 BIND arg [Ignore] to parameter [ErrorAction]
# DEBUG: 2024-03-11 19:33:31.6327 ParameterBinding Information: 0 :                     COERCE arg to [System.Management.Automation.ActionPreference]
# DEBUG: 2024-03-11 19:33:31.6328 ParameterBinding Information: 0 :                         Trying to convert argument value from System.String to System.Management.Automation.ActionPreference
# DEBUG: 2024-03-11 19:33:31.6329 ParameterBinding Information: 0 :                         CONVERT arg type to param type using LanguagePrimitives.ConvertTo
# DEBUG: 2024-03-11 19:33:31.6330 ParameterBinding Information: 0 :                         CONVERT SUCCESSFUL using LanguagePrimitives.ConvertTo: [Ignore]
# DEBUG: 2024-03-11 19:33:31.6331 ParameterBinding Information: 0 :                     BIND arg [Ignore] to param [ErrorAction] SUCCESSFUL
# DEBUG: 2024-03-11 19:33:31.6331 ParameterBinding Information: 0 :             BIND POSITIONAL cmd line args [Get-Command]
# DEBUG: 2024-03-11 19:33:31.6332 ParameterBinding Information: 0 :             MANDATORY PARAMETER CHECK on cmdlet [Get-Command]
# DEBUG: 2024-03-11 19:33:31.6333 ParameterBinding Information: 0 :             CALLING BeginProcessing
# DEBUG: 2024-03-11 19:33:31.6334 ParameterBinding Information: 0 :             CALLING ProcessRecord
# DEBUG: 2024-03-11 19:33:31.6336 ParameterBinding Information: 0 :             CALLING EndProcessing
# DEBUG: 2024-03-11 19:33:31.6339 ParameterBinding Information: 0 :             BIND NAMED cmd line args [Set-StrictMode]
# DEBUG: 2024-03-11 19:33:31.6340 ParameterBinding Information: 0 :                 BIND arg [1] to parameter [Version]
# DEBUG: 2024-03-11 19:33:31.6341 ParameterBinding Information: 0 :                     Executing DATA GENERATION metadata: [Microsoft.PowerShell.Commands.SetStrictModeCommand+ArgumentToPSVersionTransformationAttribute]
# DEBUG: 2024-03-11 19:33:31.6342 ParameterBinding Information: 0 :                         result returned from DATA GENERATION: 1.0
# DEBUG: 2024-03-11 19:33:31.6343 ParameterBinding Information: 0 :                     COERCE arg to [System.Version]
# DEBUG: 2024-03-11 19:33:31.6344 ParameterBinding Information: 0 :                         Parameter and arg types the same, no coercion is needed.
# DEBUG: 2024-03-11 19:33:31.6344 ParameterBinding Information: 0 :                     Executing VALIDATION metadata: [Microsoft.PowerShell.Commands.SetStrictModeCommand+ValidateVersionAttribute]
# DEBUG: 2024-03-11 19:33:31.6345 ParameterBinding Information: 0 :                     BIND arg [1.0] to param [Version] SUCCESSFUL
# DEBUG: 2024-03-11 19:33:31.6346 ParameterBinding Information: 0 :             BIND POSITIONAL cmd line args [Set-StrictMode]
# DEBUG: 2024-03-11 19:33:31.6347 ParameterBinding Information: 0 :             MANDATORY PARAMETER CHECK on cmdlet [Set-StrictMode]
# DEBUG: 2024-03-11 19:33:31.6347 ParameterBinding Information: 0 :             CALLING BeginProcessing
# DEBUG: 2024-03-11 19:33:31.6348 ParameterBinding Information: 0 :             CALLING ProcessRecord
# DEBUG: 2024-03-11 19:33:31.6349 ParameterBinding Information: 0 :             CALLING EndProcessing
# DEBUG: 2024-03-11 19:33:31.6352 ParameterBinding Information: 0 :             BIND NAMED cmd line args [Set-StrictMode]
# DEBUG: 2024-03-11 19:33:31.6353 ParameterBinding Information: 0 :                 BIND arg [1] to parameter [Version]
# DEBUG: 2024-03-11 19:33:31.6353 ParameterBinding Information: 0 :                     Executing DATA GENERATION metadata: [Microsoft.PowerShell.Commands.SetStrictModeCommand+ArgumentToPSVersionTransformationAttribute]
# DEBUG: 2024-03-11 19:33:31.6354 ParameterBinding Information: 0 :                         result returned from DATA GENERATION: 1.0
# DEBUG: 2024-03-11 19:33:31.6355 ParameterBinding Information: 0 :                     COERCE arg to [System.Version]
# DEBUG: 2024-03-11 19:33:31.6355 ParameterBinding Information: 0 :                         Parameter and arg types the same, no coercion is needed.
# DEBUG: 2024-03-11 19:33:31.6356 ParameterBinding Information: 0 :                     Executing VALIDATION metadata: [Microsoft.PowerShell.Commands.SetStrictModeCommand+ValidateVersionAttribute]
# DEBUG: 2024-03-11 19:33:31.6357 ParameterBinding Information: 0 :                     BIND arg [1.0] to param [Version] SUCCESSFUL
# DEBUG: 2024-03-11 19:33:31.6358 ParameterBinding Information: 0 :             BIND POSITIONAL cmd line args [Set-StrictMode]
# DEBUG: 2024-03-11 19:33:31.6358 ParameterBinding Information: 0 :             MANDATORY PARAMETER CHECK on cmdlet [Set-StrictMode]
# DEBUG: 2024-03-11 19:33:31.6359 ParameterBinding Information: 0 :             CALLING BeginProcessing
# DEBUG: 2024-03-11 19:33:31.6360 ParameterBinding Information: 0 :             CALLING ProcessRecord
# DEBUG: 2024-03-11 19:33:31.6360 ParameterBinding Information: 0 :             CALLING EndProcessing
# Get-Process:
# Line |
#    2 |  … race-Command ParameterBinding -Expression {$Foo | Get-Process} -PSHos …
#      |                                                      ~~~~~~~~~~~
#      | The input object cannot be bound to any parameters for the command either because the command does not take pipeline input or the input and its properties do not match any of the parameters that take pipeline input.
# DEBUG: 2024-03-11 19:33:31.6364 ParameterBinding Information: 0 : CALLING EndProcessing
# Command failed: SubmitCode: $Foo = [pscustomobject]@{ Bar="powershell" }; ...
